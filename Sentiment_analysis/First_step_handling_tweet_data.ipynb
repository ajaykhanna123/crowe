# %%
import pandas as pd
import numpy as np

# %%
folder_path=r"/Users/ajaykhanna/Desktop/kaggle/tweet_data/"

# %%
company_tweet=folder_path+"Company_Tweet.csv"
company=folder_path+"Company.csv"
tweet=folder_path+"Tweet.csv"

# %%
df_company_tweet=pd.read_csv(company_tweet)
df_company=pd.read_csv(company)
df_tweet=pd.read_csv(tweet)

# %%
df_company
# Out:
#   ticker_symbol company_name
# 0          AAPL        apple
# 1          GOOG   Google Inc
# 2         GOOGL   Google Inc
# 3          AMZN   Amazon.com
# 4          TSLA    Tesla Inc
# 5          MSFT    Microsoft

# %%
df_company_tweet=df_company_tweet[~df_company_tweet['tweet_id'].duplicated()]

# %%
df_tweet.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         0
# 2            0         0
# 3            0         1
# 4            0         1

# %%
df_company_tweet['ticker_symbol'].value_counts().values.sum()
# Out:
# 4336445

# %%
# df_tweet['ticker_symbol'].value_counts().values.sum()
df_tweet['tweet_id']
# Out:
#                     tweet_id           writer   post_date  \
# 0         550441509175443456  VisualStockRSRC  1420070457
# 1         550441672312512512      KeralaGuy77  1420070496
# 2         550441732014223360      DozenStocks  1420070510
# 3         550442977802207232     ShowDreamCar  1420070807
# 4         550443807834402816     i_Know_First  1420071005
# ...                      ...              ...         ...
# 3717959  1212159765914079234        TEEELAZER  1577836383
# 3717960  1212159838882533376    ShortingIsFun  1577836401
# 3717961  1212160015332728833      Commuternyc  1577836443
# 3717962  1212160410692046849      MoriaCrypto  1577836537
# 3717963  1212160477159206912         treabase  1577836553
#
#                                                       body  comment_num  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1        Insanity of today weirdo massive selling. $aap...            0
# ...

# %%
df=pd.merge(df_tweet,df_company_tweet,on='tweet_id',how='inner')

# %%
df.to_csv('tweet_data.csv')

# %%
df.set_index('tweet_id',drop=True,inplace=True)

# %%
df.isnull().sum()
# Out:
# writer           47273
# post_date            0
# body                 0
# comment_num          0
# retweet_num          0
# like_num             0
# ticker_symbol        0
# dtype: int64

# %%
df['ticker_symbol'].value_counts()
# Out:
# AAPL     1425013
# TSLA      958370
# AMZN      534008
# GOOG      312590
# MSFT      268257
# GOOGL     219726
# Name: ticker_symbol, dtype: int64

# %%
pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 125 kB 4.0 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df['body'].iloc[0]
# Out:
# 'lx21 made $10,008  on $AAPL -Check it out! http://profit.ly/1MnD8s?aff=202 Learn #howtotrade http://bit.ly/1c1NljX $EXE $WATT $IMRS $CACH $GMO'

# %%
df
# Out:
#                               writer   post_date  \
# tweet_id
# 550441509175443456   VisualStockRSRC  1420070457
# 550441672312512512       KeralaGuy77  1420070496
# 550441732014223360       DozenStocks  1420070510
# 550442977802207232      ShowDreamCar  1420070807
# 550443807834402816      i_Know_First  1420071005
# ...                              ...         ...
# 1212159765914079234        TEEELAZER  1577836383
# 1212159838882533376    ShortingIsFun  1577836401
# 1212160015332728833      Commuternyc  1577836443
# 1212160410692046849      MoriaCrypto  1577836537
# 1212160477159206912         treabase  1577836553
#
#                                                                   body  \
# tweet_id
# 550441509175443456   lx21 made $10,008  on $AAPL -Check it out! htt...
# 550441672312512512   Insanity of today weirdo massive selling. $aap...
# 550441732014223360   S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# ...

# %%
pip install nltk
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 3.1 MB/s eta 0:00:01
# ...
#   Using cached tqdm-4.61.2-py2.py3-none-any.whl (76 kB)
# ...
#      |████████████████████████████████| 693 kB 10.3 MB/s eta 0:00:01
# ...
#   Created wheel for regex: filename=regex-2021.7.6-cp38-cp38-macosx_11_0_arm64.whl size=277712 sha256=cdc93e9dbaa0f06362f99852ef9e50e0ed4e96b9bc7be86282e951aec95b1c23
#   Stored in directory: /Users/ajaykhanna/Library/Caches/pip/wheels/d9/d0/6e/90794852e9b1b7835b0439e5242aa2414cd5df4d5c4c04b627
# Successfully built regex
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/ajaykhanna/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/ajaykhanna/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/ajaykhanna/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/ajaykhanna/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/ajaykhanna/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/ajaykhanna/nltk_data...
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ajaykhanna/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ajaykhanna/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
